# %%
# Importing Boto3
# !pip3 install boto3
import boto3
import json
# Out:
# Requirement already satisfied: boto3 in /usr/local/lib/python3.9/site-packages (1.17.69)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.9/site-packages (from boto3) (0.10.0)
# Requirement already satisfied: botocore<1.21.0,>=1.20.69 in /usr/local/lib/python3.9/site-packages (from boto3) (1.20.69)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in /usr/local/lib/python3.9/site-packages (from boto3) (0.4.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.9/site-packages (from botocore<1.21.0,>=1.20.69->boto3) (1.26.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.9/site-packages (from botocore<1.21.0,>=1.20.69->boto3) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.21.0,>=1.20.69->boto3) (1.15.0)
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
text = """
*I am currently close to completing my Post Graduate Diploma in Data Science from IIIT Bangalore in collaboration with UpGrad and therefore I feel I can throw some light on the program and help others make an informed decision on choosing programs offered by UpGrad.*

*Prior to taking up the course with UpGrad, I had done a few courses from edX and Coursera platforms posted by various Universities across the globe. This, I combined with online resources and study material in hopes of making a career transition to Data Science. The fact is, we have all the required resources available online such as video material for teaching the technology, data sets to gain coding knowledge and other materials to teach us about the business domain. Honestly, after about 4 months of trying to crack data science this way (the hard way), it didn’t seem like I was making any headway. I was nowhere close to understanding an industry which is not an IT discipline at all, but rather a field which combines Mathematics, Coding and above all Business domain.*

*This is when I found out about the PGDDS course offered by UpGrad which provided a definite structure in the vast ocean of information about the Data Science Industry available online. It gave the benefit of a structured program rather than spending or wasting huge amounts of time just trying to accumulate all the resources required to make some headway. Simply put, it saved me the effort of searching for needles in a mammoth haystack (internet).*

*So I signed up for the program and after completing 10 months of the 11 month program, here are the few benefits I have felt.*

*1. First and foremost, this is not a certification course but a Post Graduate Diploma provided by an accredited University that carries a lot of value than any certification course. Let’s be honest, any company would always value a university degree over any online certification course.*

*2. Faculty who teach different modules are top notch in their fields having Doctorate or Master’s degree. Further, since Data Science is inter-disciplinary in nature, therefore we would require faculties with experience in the relevant disciplines to guide us. IIIT-B in collaboration with UpGrad have chosen faculties with the right qualification to match with the different disciplines.*

*3. Moreover, UpGrad has tied up with industry professionals working at companies such as Gramener, Uber, Flipkart etc. to provide the students with a course that makes it more aligned with the happenings in the current Data Science Industry. They also let you work on case studies using real time data (as opposed to fabricated data) providing us with exposure to actual problems in the industry being solved using Data Analytics.*

*4. UpGrad has further tied up with a third party company known as Tapchief to allow us to interact with top professionals in the industry. This is aimed at giving us guidance on how we can further our career in the field considering our educational qualification, past experiences, our expectation or goals, and age. They also help in guiding us in our final Capstone Project through video chats and main benefit of this is to guide us in terms of realistic approaches to the problem and providing business insights into the given problems.*

*5. Biggest benefit: Networking!!! The biggest benefit I have received is being able to collaborate with so many other students who are industry professionals at different stages of the course. Numerous opportunities are given to interact with this diverse group of people such as working in groups on numerous case studies, meeting them at basecamps arranged by UpGrad and lot of us can meet up at campus library if you are from Bangalore.*

*UpGrad is trying to tackle a concern or a problem which has been voiced by so many CEO’s of top IT organizations: EMPLOYABILITY. They do this by collaborating not just with an academic institute, but also bringing in industry experts to give us the right tools required in the market.*

*I understand the course fees are on the upper side compared to many other online and offline courses offered, but I don’t personally believe there are many platforms which offer a holistic package such as the one’s UpGrad offered.*

*I hope this review helps anyone wishing to pursue a course offered by UpGrad and I must say, taking up any of the courses is serious business and will require serious time and effort from the candidates.

"""

# %%
client = boto3.client('comprehend', aws_access_key_id="AKIAWZ42OIVQELVZVQQZ",aws_secret_access_key= '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')

# %%
#### Question 1.

# Which of the following commands will help you get the gist of the review?

# - detect_entities
# - detect_sentiment
# - detect_key_phrases
# - detect_syntax

# Ans: detect_key_phrases

print('Calling DetectKeyPhrases')
context = json.dumps(client.detect_key_phrases(Text=text, LanguageCode='en'), sort_keys=True, indent=4)
print(context)
print('End of DetectKeyPhrases\n')
# Out:
# Calling DetectKeyPhrases
# {
#     "KeyPhrases": [
#         {
#             "BeginOffset": 37,
#             "EndOffset": 61,
#             "Score": 0.999993622303009,
#             "Text": "my Post Graduate Diploma"
#         },
#         {
#             "BeginOffset": 65,
#             "EndOffset": 77,
#             "Score": 0.9999895691871643,
#             "Text": "Data Science"
#         },
#         {
#             "BeginOffset": 83,
#             "EndOffset": 97,
#             "Score": 0.9999783635139465,
#             "Text": "IIIT Bangalore"
#         },
#         {
#             "BeginOffset": 101,
#             "EndOffset": 114,
#             "Score": 0.9999651908874512,
#             "Text": "collaboration"
#         },
#         {
#             "BeginOffset": 120,
#             "EndOffset": 126,
#             "Score": 0.9999974966049194,
#             "Text": "UpGrad"
#         },
#         {
#             "BeginOffset": 160,
#             "EndOffset": 170,
#             "Score": 0.9999995231628418,
#             "Text": "some light"
#         },
#         {
#             "BeginOffset": 174,
#             "EndOffset": 185,
#             "Score": 1.0,
#             "Text": "the program"
#         },
#         {
#             "BeginOffset": 207,
#             "EndOffset": 227,
#             "Score": 0.9999999403953552,
#             "Text": "an informed decision"
#         },
#         {
#             "BeginOffset": 240,
#             "EndOffset": 248,
#             "Score": 0.9999994039535522,
#             "Text": "programs"
#         },
#         {
#             "BeginOffset": 260,
#             "EndOffset": 266,
#             "Score": 0.9999926090240479,
#             "Text": "UpGrad"
#         },
#         {
#             "BeginOffset": 290,
#             "EndOffset": 300,
#             "Score": 0.9999985694885254,
#             "Text": "the course"
#         },
#         {
#             "BeginOffset": 306,
#             "EndOffset": 312,
#             "Score": 0.9999910593032837,
#             "Text": "UpGrad"
#         },
#         {
#             "BeginOffset": 325,
#             "EndOffset": 338,
#             "Score": 0.9999954104423523,
#             "Text": "a few courses"
#         },
#         {
#             "BeginOffset": 344,
#             "EndOffset": 347,
#             "Score": 0.9999772310256958,
#             "Text": "edX"
#         },
#         {
#             "BeginOffset": 352,
#             "EndOffset": 370,
#             "Score": 0.9891889691352844,
#             "Text": "Coursera platforms"
#         },
#         {
#             "BeginOffset": 381,
#             "EndOffset": 401,
#             "Score": 0.9995207786560059,
#             "Text": "various Universities"
#         },
#         {
#             "BeginOffset": 409,
#             "EndOffset": 418,
#             "Score": 0.9999984502792358,
#             "Text": "the globe"
#         },
#         {
#             "BeginOffset": 442,
#             "EndOffset": 477,
#             "Score": 0.8751158118247986,
#             "Text": "online resources and study material"
#         },
#         {
#             "BeginOffset": 481,
#             "EndOffset": 486,
#             "Score": 0.9999990463256836,
#             "Text": "hopes"
#         },
#         {
#             "BeginOffset": 497,
#             "EndOffset": 516,
#             "Score": 0.9999775290489197,
#             "Text": "a career transition"
#         },
#         {
#             "BeginOffset": 520,
#             "EndOffset": 532,
#             "Score": 0.9999912977218628,
#             "Text": "Data Science"
#         },
#         {
#             "BeginOffset": 534,
#             "EndOffset": 542,
#             "Score": 0.9999966025352478,
#             "Text": "The fact"
#         },
#         {
#             "BeginOffset": 555,
#             "EndOffset": 581,
#             "Score": 0.99997878074646,
#             "Text": "all the required resources"
#         },
#         {
#             "BeginOffset": 607,
#             "EndOffset": 621,
#             "Score": 0.9998860955238342,
#             "Text": "video material"
#         },
#         {
#             "BeginOffset": 635,
#             "EndOffset": 649,
#             "Score": 0.9999999403953552,
#             "Text": "the technology"
#         },
#         {
#             "BeginOffset": 651,
#             "EndOffset": 655,
#             "Score": 0.9999819993972778,
#             "Text": "data"
#         },
#         {
#             "BeginOffset": 669,
#             "EndOffset": 675,
#             "Score": 0.7371898889541626,
#             "Text": "coding"
#         },
#         {
#             "BeginOffset": 676,
#             "EndOffset": 705,
#             "Score": 0.9491260647773743,
#             "Text": "knowledge and other materials"
#         },
#         {
#             "BeginOffset": 724,
#             "EndOffset": 743,
#             "Score": 0.9999952912330627,
#             "Text": "the business domain"
#         },
#         {
#             "BeginOffset": 761,
#             "EndOffset": 775,
#             "Score": 0.9999548196792603,
#             "Text": "about 4 months"
#         },
#         {
#             "BeginOffset": 795,
#             "EndOffset": 807,
#             "Score": 0.9999806880950928,
#             "Text": "data science"
#         },
#         {
#             "BeginOffset": 808,
#             "EndOffset": 816,
#             "Score": 0.9999896287918091,
#             "Text": "this way"
#         },
#         {
#             "BeginOffset": 818,
#             "EndOffset": 830,
#             "Score": 0.99998539686203,
#             "Text": "the hard way"
#         },
#         {
#             "BeginOffset": 866,
#             "EndOffset": 877,
#             "Score": 0.9999933838844299,
#             "Text": "any headway"
#         },
#         {
#             "BeginOffset": 916,
#             "EndOffset": 927,
#             "Score": 0.9999996423721313,
#             "Text": "an industry"
#         },
#         {
#             "BeginOffset": 941,
#             "EndOffset": 957,
#             "Score": 0.9999931454658508,
#             "Text": "an IT discipline"
#         },
#         {
#             "BeginOffset": 977,
#             "EndOffset": 984,
#             "Score": 0.9999980330467224,
#             "Text": "a field"
#         },
#         {
#             "BeginOffset": 1000,
#             "EndOffset": 1019,
#             "Score": 0.7782031893730164,
#             "Text": "Mathematics, Coding"
#         },
#         {
#             "BeginOffset": 1030,
#             "EndOffset": 1049,
#             "Score": 0.9999362826347351,
#             "Text": "all Business domain"
#         },
#         {
#             "BeginOffset": 1085,
#             "EndOffset": 1101,
#             "Score": 0.9999999403953552,
#             "Text": "the PGDDS course"
#         },
#         {
#             "BeginOffset": 1113,
#             "EndOffset": 1119,
#             "Score": 0.9999418258666992,
#             "Text": "UpGrad"
#         },
#         {
#             "BeginOffset": 1135,
#             "EndOffset": 1155,
#             "Score": 0.9999998211860657,
#             "Text": "a definite structure"
#         },
#         {
#             "BeginOffset": 1159,
#             "EndOffset": 1173,
#             "Score": 0.9999997019767761,
#             "Text": "the vast ocean"
#         },
#         {
#             "BeginOffset": 1177,
#             "EndOffset": 1188,
#             "Score": 0.9993014335632324,
#             "Text": "information"
#         },
#         {
#             "BeginOffset": 1195,
#             "EndOffset": 1220,
#             "Score": 0.9999898076057434,
#             "Text": "the Data Science Industry"
#         },
#         {
#             "BeginOffset": 1247,
#             "EndOffset": 1258,
#             "Score": 0.9999994039535522,
#             "Text": "the benefit"
#         },
#         {
#             "BeginOffset": 1262,
#             "EndOffset": 1282,
#             "Score": 0.9999613165855408,
#             "Text": "a structured program"
#         },
#         {
#             "BeginOffset": 1315,
#             "EndOffset": 1327,
#             "Score": 0.9964463710784912,
#             "Text": "huge amounts"
#         },
#         {
#             "BeginOffset": 1331,
#             "EndOffset": 1335,
#             "Score": 0.9955077171325684,
#             "Text": "time"
#         },
#         {
#             "BeginOffset": 1362,
#             "EndOffset": 1379,
#             "Score": 0.9999991655349731,
#             "Text": "all the resources"
#         },
#         {
#             "BeginOffset": 1397,
#             "EndOffset": 1409,
#             "Score": 0.9999946355819702,
#             "Text": "some headway"
#         },
#         {
#             "BeginOffset": 1435,
#             "EndOffset": 1445,
#             "Score": 0.9998530149459839,
#             "Text": "the effort"
#         },
#         {
#             "BeginOffset": 1463,
#             "EndOffset": 1470,
#             "Score": 0.9999508857727051,
#             "Text": "needles"
#         },
#         {
#             "BeginOffset": 1474,
#             "EndOffset": 1492,
#             "Score": 0.9999889731407166,
#             "Text": "a mammoth haystack"
#         },
#         {
#             "BeginOffset": 1494,
#             "EndOffset": 1502,
#             "Score": 0.9999696016311646,
#             "Text": "internet"
#         },
#         {
#             "BeginOffset": 1527,
#             "EndOffset": 1538,
#             "Score": 1.0,
#             "Text": "the program"
#         },
#         {
#             "BeginOffset": 1560,
#             "EndOffset": 1569,
#             "Score": 0.9999986290931702,
#             "Text": "10 months"
#         },
#         {
#             "BeginOffset": 1573,
#             "EndOffset": 1593,
#             "Score": 0.9999971985816956,
#             "Text": "the 11 month program"
#         },
#         {
#             "BeginOffset": 1604,
#             "EndOffset": 1620,
#             "Score": 0.9999833703041077,
#             "Text": "the few benefits"
#         },
#         {
#             "BeginOffset": 1637,
#             "EndOffset": 1638,
#             "Score": 0.949975311756134,
#             "Text": "1"
#         },
#         {
#             "BeginOffset": 1672,
#             "EndOffset": 1694,
#             "Score": 0.9999988675117493,
#             "Text": "a certification course"
#         },
#         {
#             "BeginOffset": 1699,
#             "EndOffset": 1722,
#             "Score": 0.9999469518661499,
#             "Text": "a Post Graduate Diploma"
#         },
#         {
#             "BeginOffset": 1735,
#             "EndOffset": 1759,
#             "Score": 0.9999943375587463,
#             "Text": "an accredited University"
#         },
#         {
#             "BeginOffset": 1773,
#             "EndOffset": 1778,
#             "Score": 0.9999998807907104,
#             "Text": "a lot"
#         },
#         {
#             "BeginOffset": 1793,
#             "EndOffset": 1817,
#             "Score": 0.999997615814209,
#             "Text": "any certification course"
#         },
#         {
#             "BeginOffset": 1836,
#             "EndOffset": 1847,
#             "Score": 0.9999978542327881,
#             "Text": "any company"
#         },
#         {
#             "BeginOffset": 1867,
#             "EndOffset": 1886,
#             "Score": 0.9999584555625916,
#             "Text": "a university degree"
#         },
#         {
#             "BeginOffset": 1892,
#             "EndOffset": 1923,
#             "Score": 0.9999553561210632,
#             "Text": "any online certification course"
#         },
#         {
#             "BeginOffset": 1928,
#             "EndOffset": 1929,
#             "Score": 0.9990260601043701,
#             "Text": "2"
#         },
#         {
#             "BeginOffset": 1931,
#             "EndOffset": 1938,
#             "Score": 0.999927282333374,
#             "Text": "Faculty"
#         },
#         {
#             "BeginOffset": 1949,
#             "EndOffset": 1966,
#             "Score": 0.9999982714653015,
#             "Text": "different modules"
#         },
#         {
#             "BeginOffset": 1971,
#             "EndOffset": 1980,
#             "Score": 0.9999279975891113,
#             "Text": "top notch"
#         },
#         {
#             "BeginOffset": 1984,
#             "EndOffset": 1996,
#             "Score": 0.9999989867210388,
#             "Text": "their fields"
#         },
#         {
#             "BeginOffset": 2004,
#             "EndOffset": 2023,
#             "Score": 0.98129802942276,
#             "Text": "Doctorate or Master"
#         },
#         {
#             "BeginOffset": 2023,
#             "EndOffset": 2032,
#             "Score": 0.9999962449073792,
#             "Text": "\u2019s degree"
#         },
#         {
#             "BeginOffset": 2049,
#             "EndOffset": 2061,
#             "Score": 0.9894614815711975,
#             "Text": "Data Science"
#         },
#         {
#             "BeginOffset": 2087,
#             "EndOffset": 2093,
#             "Score": 0.9997081160545349,
#             "Text": "nature"
#         },
#         {
#             "BeginOffset": 2122,
#             "EndOffset": 2131,
#             "Score": 0.9999951124191284,
#             "Text": "faculties"
#         },
#         {
#             "BeginOffset": 2137,
#             "EndOffset": 2147,
#             "Score": 0.999982476234436,
#             "Text": "experience"
#         },
#         {
#             "BeginOffset": 2151,
#             "EndOffset": 2175,
#             "Score": 0.9999849200248718,
#             "Text": "the relevant disciplines"
#         },
#         {
#             "BeginOffset": 2199,
#             "EndOffset": 2212,
#             "Score": 0.999998927116394,
#             "Text": "collaboration"
#         },
#         {
#             "BeginOffset": 2218,
#             "EndOffset": 2224,
#             "Score": 0.9998986721038818,
#             "Text": "UpGrad"
#         },
#         {
#             "BeginOffset": 2237,
#             "EndOffset": 2246,
#             "Score": 0.9999881982803345,
#             "Text": "faculties"
#         },
#         {
#             "BeginOffset": 2252,
#             "EndOffset": 2275,
#             "Score": 0.9997435808181763,
#             "Text": "the right qualification"
#         },
#         {
#             "BeginOffset": 2290,
#             "EndOffset": 2315,
#             "Score": 0.9999528527259827,
#             "Text": "the different disciplines"
#         },
#         {
#             "BeginOffset": 2320,
#             "EndOffset": 2321,
#             "Score": 0.9894459843635559,
#             "Text": "3"
#         },
#         {
#             "BeginOffset": 2333,
#             "EndOffset": 2339,
#             "Score": 0.9999059438705444,
#             "Text": "UpGrad"
#         },
#         {
#             "BeginOffset": 2357,
#             "EndOffset": 2379,
#             "Score": 0.999957799911499,
#             "Text": "industry professionals"
#         },
#         {
#             "BeginOffset": 2391,
#             "EndOffset": 2400,
#             "Score": 0.9999979734420776,
#             "Text": "companies"
#         },
#         {
#             "BeginOffset": 2409,
#             "EndOffset": 2438,
#             "Score": 0.9971787929534912,
#             "Text": "Gramener, Uber, Flipkart etc."
#         },
#         {
#             "BeginOffset": 2450,
#             "EndOffset": 2462,
#             "Score": 0.9999991059303284,
#             "Text": "the students"
#         },
#         {
#             "BeginOffset": 2468,
#             "EndOffset": 2476,
#             "Score": 1.0,
#             "Text": "a course"
#         },
#         {
#             "BeginOffset": 2509,
#             "EndOffset": 2523,
#             "Score": 0.9999832510948181,
#             "Text": "the happenings"
#         },
#         {
#             "BeginOffset": 2527,
#             "EndOffset": 2560,
#             "Score": 0.9999851584434509,
#             "Text": "the current Data Science Industry"
#         },
#         {
#             "BeginOffset": 2588,
#             "EndOffset": 2600,
#             "Score": 0.9999645352363586,
#             "Text": "case studies"
#         },
#         {
#             "BeginOffset": 2607,
#             "EndOffset": 2621,
#             "Score": 0.9999930262565613,
#             "Text": "real time data"
#         },
#         {
#             "BeginOffset": 2637,
#             "EndOffset": 2652,
#             "Score": 0.9996203184127808,
#             "Text": "fabricated data"
#         },
#         {
#             "BeginOffset": 2672,
#             "EndOffset": 2680,
#             "Score": 0.9994444251060486,
#             "Text": "exposure"
#         },
#         {
#             "BeginOffset": 2684,
#             "EndOffset": 2699,
#             "Score": 0.9999991655349731,
#             "Text": "actual problems"
#         },
#         {
#             "BeginOffset": 2703,
#             "EndOffset": 2715,
#             "Score": 0.9999999403953552,
#             "Text": "the industry"
#         },
#         {
#             "BeginOffset": 2735,
#             "EndOffset": 2749,
#             "Score": 0.9999659657478333,
#             "Text": "Data Analytics"
#         },
#         {
#             "BeginOffset": 2754,
#             "EndOffset": 2755,
#             "Score": 0.9955211877822876,
#             "Text": "4"
#         },
#         {
#             "BeginOffset": 2757,
#             "EndOffset": 2763,
#             "Score": 0.9961275458335876,
#             "Text": "UpGrad"
#         },
#         {
#             "BeginOffset": 2789,
#             "EndOffset": 2810,
#             "Score": 0.9999967217445374,
#             "Text": "a third party company"
#         },
#         {
#             "BeginOffset": 2820,
#             "EndOffset": 2828,
#             "Score": 0.9999059438705444,
#             "Text": "Tapchief"
#         },
#         {
#             "BeginOffset": 2858,
#             "EndOffset": 2875,
#             "Score": 0.999996542930603,
#             "Text": "top professionals"
#         },
#         {
#             "BeginOffset": 2879,
#             "EndOffset": 2891,
#             "Score": 0.9999986886978149,
#             "Text": "the industry"
#         },
#         {
#             "BeginOffset": 2951,
#             "EndOffset": 2961,
#             "Score": 0.9999986886978149,
#             "Text": "our career"
#         },
#         {
#             "BeginOffset": 2965,
#             "EndOffset": 2974,
#             "Score": 0.9999993443489075,
#             "Text": "the field"
#         },
#         {
#             "BeginOffset": 2987,
#             "EndOffset": 3016,
#             "Score": 0.9999997615814209,
#             "Text": "our educational qualification"
#         },
#         {
#             "BeginOffset": 3018,
#             "EndOffset": 3034,
#             "Score": 0.9999642968177795,
#             "Text": "past experiences"
#         },
#         {
#             "BeginOffset": 3036,
#             "EndOffset": 3060,
#             "Score": 0.9682688117027283,
#             "Text": "our expectation or goals"
#         },
#         {
#             "BeginOffset": 3066,
#             "EndOffset": 3069,
#             "Score": 0.9999765157699585,
#             "Text": "age"
#         },
#         {
#             "BeginOffset": 3103,
#             "EndOffset": 3129,
#             "Score": 0.9999645948410034,
#             "Text": "our final Capstone Project"
#         },
#         {
#             "BeginOffset": 3138,
#             "EndOffset": 3149,
#             "Score": 0.9999847412109375,
#             "Text": "video chats"
#         },
#         {
#             "BeginOffset": 3154,
#             "EndOffset": 3166,
#             "Score": 0.9998533129692078,
#             "Text": "main benefit"
#         },
#         {
#             "BeginOffset": 3193,
#             "EndOffset": 3198,
#             "Score": 0.9999994039535522,
#             "Text": "terms"
#         },
#         {
#             "BeginOffset": 3202,
#             "EndOffset": 3222,
#             "Score": 0.9999845623970032,
#             "Text": "realistic approaches"
#         },
#         {
#             "BeginOffset": 3226,
#             "EndOffset": 3237,
#             "Score": 0.999999463558197,
#             "Text": "the problem"
#         },
#         {
#             "BeginOffset": 3252,
#             "EndOffset": 3269,
#             "Score": 0.9986981153488159,
#             "Text": "business insights"
#         },
#         {
#             "BeginOffset": 3275,
#             "EndOffset": 3293,
#             "Score": 0.9993149638175964,
#             "Text": "the given problems"
#         },
#         {
#             "BeginOffset": 3298,
#             "EndOffset": 3299,
#             "Score": 0.9866296052932739,
#             "Text": "5"
#         },
#         {
#             "BeginOffset": 3301,
#             "EndOffset": 3316,
#             "Score": 0.7072901129722595,
#             "Text": "Biggest benefit"
#         },
#         {
#             "BeginOffset": 3332,
#             "EndOffset": 3351,
#             "Score": 0.9999017119407654,
#             "Text": "The biggest benefit"
#         },
#         {
#             "BeginOffset": 3402,
#             "EndOffset": 3424,
#             "Score": 0.999737024307251,
#             "Text": "so many other students"
#         },
#         {
#             "BeginOffset": 3433,
#             "EndOffset": 3455,
#             "Score": 0.9999987483024597,
#             "Text": "industry professionals"
#         },
#         {
#             "BeginOffset": 3459,
#             "EndOffset": 3475,
#             "Score": 0.9999992847442627,
#             "Text": "different stages"
#         },
#         {
#             "BeginOffset": 3479,
#             "EndOffset": 3489,
#             "Score": 0.9999996423721313,
#             "Text": "the course"
#         },
#         {
#             "BeginOffset": 3491,
#             "EndOffset": 3513,
#             "Score": 0.9999969005584717,
#             "Text": "Numerous opportunities"
#         },
#         {
#             "BeginOffset": 3541,
#             "EndOffset": 3559,
#             "Score": 0.9999998807907104,
#             "Text": "this diverse group"
#         },
#         {
#             "BeginOffset": 3563,
#             "EndOffset": 3569,
#             "Score": 0.9999889135360718,
#             "Text": "people"
#         },
#         {
#             "BeginOffset": 3589,
#             "EndOffset": 3595,
#             "Score": 0.9999973773956299,
#             "Text": "groups"
#         },
#         {
#             "BeginOffset": 3599,
#             "EndOffset": 3620,
#             "Score": 0.9999972581863403,
#             "Text": "numerous case studies"
#         },
#         {
#             "BeginOffset": 3638,
#             "EndOffset": 3647,
#             "Score": 0.9999723434448242,
#             "Text": "basecamps"
#         },
#         {
#             "BeginOffset": 3660,
#             "EndOffset": 3666,
#             "Score": 0.9999964237213135,
#             "Text": "UpGrad"
#         },
#         {
#             "BeginOffset": 3671,
#             "EndOffset": 3674,
#             "Score": 0.9988794922828674,
#             "Text": "lot"
#         },
#         {
#             "BeginOffset": 3696,
#             "EndOffset": 3710,
#             "Score": 0.9999918937683105,
#             "Text": "campus library"
#         },
#         {
#             "BeginOffset": 3727,
#             "EndOffset": 3736,
#             "Score": 0.999995231628418,
#             "Text": "Bangalore"
#         },
#         {
#             "BeginOffset": 3741,
#             "EndOffset": 3747,
#             "Score": 0.9481432437896729,
#             "Text": "UpGrad"
#         },
#         {
#             "BeginOffset": 3768,
#             "EndOffset": 3777,
#             "Score": 0.999999463558197,
#             "Text": "a concern"
#         },
#         {
#             "BeginOffset": 3781,
#             "EndOffset": 3790,
#             "Score": 0.9999996423721313,
#             "Text": "a problem"
#         },
#         {
#             "BeginOffset": 3816,
#             "EndOffset": 3827,
#             "Score": 0.7917431592941284,
#             "Text": "so many CEO"
#         },
#         {
#             "BeginOffset": 3833,
#             "EndOffset": 3853,
#             "Score": 0.9996592402458191,
#             "Text": "top IT organizations"
#         },
#         {
#             "BeginOffset": 3914,
#             "EndOffset": 3935,
#             "Score": 0.999997079372406,
#             "Text": "an academic institute"
#         },
#         {
#             "BeginOffset": 3958,
#             "EndOffset": 3974,
#             "Score": 0.9999945759773254,
#             "Text": "industry experts"
#         },
#         {
#             "BeginOffset": 3986,
#             "EndOffset": 4001,
#             "Score": 0.9999451637268066,
#             "Text": "the right tools"
#         },
#         {
#             "BeginOffset": 4014,
#             "EndOffset": 4024,
#             "Score": 0.9999995231628418,
#             "Text": "the market"
#         },
#         {
#             "BeginOffset": 4042,
#             "EndOffset": 4057,
#             "Score": 0.9998089075088501,
#             "Text": "the course fees"
#         },
#         {
#             "BeginOffset": 4065,
#             "EndOffset": 4079,
#             "Score": 0.9999999403953552,
#             "Text": "the upper side"
#         },
#         {
#             "BeginOffset": 4092,
#             "EndOffset": 4129,
#             "Score": 0.9999975562095642,
#             "Text": "many other online and offline courses"
#         },
#         {
#             "BeginOffset": 4180,
#             "EndOffset": 4194,
#             "Score": 0.9999943971633911,
#             "Text": "many platforms"
#         },
#         {
#             "BeginOffset": 4207,
#             "EndOffset": 4225,
#             "Score": 0.9999993443489075,
#             "Text": "a holistic package"
#         },
#         {
#             "BeginOffset": 4234,
#             "EndOffset": 4241,
#             "Score": 0.9999992847442627,
#             "Text": "the one"
#         },
#         {
#             "BeginOffset": 4241,
#             "EndOffset": 4250,
#             "Score": 0.9999644160270691,
#             "Text": "\u2019s UpGrad"
#         },
#         {
#             "BeginOffset": 4270,
#             "EndOffset": 4281,
#             "Score": 0.9999988079071045,
#             "Text": "this review"
#         },
#         {
#             "BeginOffset": 4313,
#             "EndOffset": 4321,
#             "Score": 1.0,
#             "Text": "a course"
#         },
#         {
#             "BeginOffset": 4333,
#             "EndOffset": 4339,
#             "Score": 0.9999990463256836,
#             "Text": "UpGrad"
#         },
#         {
#             "BeginOffset": 4373,
#             "EndOffset": 4384,
#             "Score": 0.9999995231628418,
#             "Text": "the courses"
#         },
#         {
#             "BeginOffset": 4388,
#             "EndOffset": 4404,
#             "Score": 0.9999996423721313,
#             "Text": "serious business"
#         },
#         {
#             "BeginOffset": 4422,
#             "EndOffset": 4445,
#             "Score": 0.9999984502792358,
#             "Text": "serious time and effort"
#         },
#         {
#             "BeginOffset": 4451,
#             "EndOffset": 4465,
#             "Score": 0.9999987483024597,
#             "Text": "the candidates"
#         }
#     ],
#     "ResponseMetadata": {
#         "HTTPHeaders": {
#             "content-length": "14136",
#             "content-type": "application/x-amz-json-1.1",
#             "date": "Sun, 09 May 2021 14:35:06 GMT",
#             "x-amzn-requestid": "057c93ac-034f-4438-9896-c21f99ea44ab"
#         },
#         "HTTPStatusCode": 200,
#         "RequestId": "057c93ac-034f-4438-9896-c21f99ea44ab",
#         "RetryAttempts": 0
#     }
# }
# End of DetectKeyPhrases

# %%
# Which of the following companies is not listed in the review?
# 
# - upGrad
# - Gramener
# - Flipkart
# - Ola
entities = client.detect_entities(Text = text, LanguageCode = 'en') #API call for entity extraction
entities = entities['Entities'] #all entities
print(entities)
textEntities = [dict_item['Text'].lower() for dict_item in entities] #the text that has been identified as entities
typeEntities = [dict_item['Type'] for dict_item in entities] #the type of entity the text is
input_companies = ['upGrad', "Gramener", "Flipkart", "Ola"]
not_listed_companies = []
for item in input_companies:
    if item.lower() not in set(textEntities):
        not_listed_companies.append(item)
print("Following companies are not listed in the review", not_listed_companies)
# Out:
# [{'Score': 0.9553999304771423, 'Type': 'ORGANIZATION', 'Text': 'IIIT Bangalore', 'BeginOffset': 83, 'EndOffset': 97}, {'Score': 0.93536776304245, 'Type': 'ORGANIZATION', 'Text': 'UpGrad', 'BeginOffset': 120, 'EndOffset': 126}, {'Score': 0.761984646320343, 'Type': 'ORGANIZATION', 'Text': 'UpGrad', 'BeginOffset': 260, 'EndOffset': 266}, {'Score': 0.8620490431785583, 'Type': 'ORGANIZATION', 'Text': 'UpGrad', 'BeginOffset': 306, 'EndOffset': 312}, {'Score': 0.5144599676132202, 'Type': 'ORGANIZATION', 'Text': 'edX', 'BeginOffset': 344, 'EndOffset': 347}, {'Score': 0.6463546752929688, 'Type': 'ORGANIZATION', 'Text': 'Coursera', 'BeginOffset': 352, 'EndOffset': 360}, {'Score': 0.8610247373580933, 'Type': 'QUANTITY', 'Text': 'about 4 months', 'BeginOffset': 761, 'EndOffset': 775}, {'Score': 0.40871143341064453, 'Type': 'ORGANIZATION', 'Text': 'PGDDS', 'BeginOffset': 1089, 'EndOffset': 1094}, {'Score': 0.9757153391838074, 'Type': 'ORGANIZATION', 'Text': 'UpGrad', 'BeginOffset': 1113, 'EndOffset': 1119}, {'Score': 0.996462881565094, 'Type': 'QUANTITY', 'Text': '10 months', 'BeginOffset': 1560, 'EndOffset': 1569}, {'Score': 0.9813646674156189, 'Type': 'QUANTITY', 'Text': '11 month', 'BeginOffset': 1577, 'EndOffset': 1585}, {'Score': 0.8784805536270142, 'Type': 'QUANTITY', 'Text': 'First', 'BeginOffset': 1640, 'EndOffset': 1645}, {'Score': 0.46338164806365967, 'Type': 'OTHER', 'Text': 'IIIT', 'BeginOffset': 2189, 'EndOffset': 2193}, {'Score': 0.9923851490020752, 'Type': 'ORGANIZATION', 'Text': 'UpGrad', 'BeginOffset': 2218, 'EndOffset': 2224}, {'Score': 0.995943009853363, 'Type': 'ORGANIZATION', 'Text': 'UpGrad', 'BeginOffset': 2333, 'EndOffset': 2339}, {'Score': 0.9990079998970032, 'Type': 'ORGANIZATION', 'Text': 'Gramener', 'BeginOffset': 2409, 'EndOffset': 2417}, {'Score': 0.9996422529220581, 'Type': 'ORGANIZATION', 'Text': 'Uber', 'BeginOffset': 2419, 'EndOffset': 2423}, {'Score': 0.9995959401130676, 'Type': 'ORGANIZATION', 'Text': 'Flipkart', 'BeginOffset': 2425, 'EndOffset': 2433}, {'Score': 0.3806703984737396, 'Type': 'TITLE', 'Text': 'Data', 'BeginOffset': 2735, 'EndOffset': 2739}, {'Score': 0.9976024031639099, 'Type': 'ORGANIZATION', 'Text': 'UpGrad', 'BeginOffset': 2757, 'EndOffset': 2763}, {'Score': 0.9922882914543152, 'Type': 'ORGANIZATION', 'Text': 'Tapchief', 'BeginOffset': 2820, 'EndOffset': 2828}, {'Score': 0.9927660226821899, 'Type': 'ORGANIZATION', 'Text': 'UpGrad', 'BeginOffset': 3660, 'EndOffset': 3666}, {'Score': 0.998143196105957, 'Type': 'LOCATION', 'Text': 'Bangalore', 'BeginOffset': 3727, 'EndOffset': 3736}, {'Score': 0.9984318614006042, 'Type': 'ORGANIZATION', 'Text': 'UpGrad', 'BeginOffset': 3741, 'EndOffset': 3747}, {'Score': 0.8992147445678711, 'Type': 'ORGANIZATION', 'Text': 'UpGrad', 'BeginOffset': 4244, 'EndOffset': 4250}, {'Score': 0.9444661736488342, 'Type': 'ORGANIZATION', 'Text': 'UpGrad', 'BeginOffset': 4333, 'EndOffset': 4339}]
# Following companies are not listed in the review ['Ola']
